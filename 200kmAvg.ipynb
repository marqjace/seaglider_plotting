# %% [markdown]
# # Imports

# %%
import numpy as np
import numpy.ma as ma
import xarray as xr
import matplotlib.pyplot as plt
from scipy.interpolate import griddata
import cmocean
from matplotlib import colors
import glidertools as gt
from datetime import datetime, timedelta
import pandas as pd
from matplotlib.dates import DateFormatter

# %% [markdown]
# # Open WOA Climatology Data
# Data Access Here: https://www.ncei.noaa.gov/access/world-ocean-atlas-2018/bin/woa18.pl

# %% [markdown]
# ## January

# %%
# Open WOA Climatology Dataset and Select the TH Line transect

ds1 = xr.open_dataset(r'C:\Users\marqjace\t_anom\woa_climatology_data\woa18_decav_t01_01.nc', decode_times=False)


# Select the extent of the TH Line 200km inshore (-126.5 to -123.5W longitude, 0-1000m depth)

ds1 = ds1.sel(lat=41.5, lon=slice(-126.5, -123.5), depth=slice(0,1000))


# Name the variables

t_an1 = ds1['t_an'][0,:,:]  # Temperature
lon1 = ds1['lon']  # Longitude
lat1 = ds1['lat']  # Latitude
depth1 = ds1['depth']  # Depth


# Define a new grid (112 points longitude, 200 points depth)

z_new1 = np.arange(0,1000, 5)
lon_new1 = np.arange(-126.5, -123.5, 0.0625)


# Linearly interpolate the dataset "ds" across the new defined grid

ds_z_new1 = ds1.interp(depth=z_new1, lon=lon_new1)


# Meshgrid the longitude and depth grid

Xgrid1, Ygrid1 = np.meshgrid(ds_z_new1['lon'], ds_z_new1['depth'])


# Define new temperature variable dimensions. We only want longitude and depth

ds_z_t_an1 = ds_z_new1['t_an'][0,:,:]


# Print the shapes to show how the grid changed the temperature data. Note that the shapes look transposed.
# This is because of the np.meshgrid() function.

print(f'Original Grid Shape VS New Grid Shape:\nOriginal temperature value shape: {t_an1.shape}\nGridded temperature value shape: {ds_z_t_an1.shape}')
# Out:
# Original Grid Shape VS New Grid Shape:
# Original temperature value shape: (47, 4)
# Gridded temperature value shape: (200, 48)

# %% [markdown]
# ## February

# %%
# Open WOA Climatology Dataset and Select the TH Line transect

ds2 = xr.open_dataset(r'C:\Users\marqjace\t_anom\woa_climatology_data\woa18_decav_t02_01.nc', decode_times=False)


# Select the extent of the TH Line 200km inshore (-126.5 to -123.5W longitude, 0-1000m depth)

ds2 = ds2.sel(lat=41.5, lon=slice(-126.5, -123.5), depth=slice(0,1000))


# Name the variables

t_an2 = ds2['t_an'][0,:,:]  # Temperature
lon2 = ds2['lon']  # Longitude
lat2 = ds2['lat']  # Latitude
depth2 = ds2['depth']  # Depth


# Define a new grid (112 points longitude, 200 points depth)

z_new2 = np.arange(0,1000, 5)
lon_new2 = np.arange(-126.5, -123.5, 0.0625)


# Linearly interpolate the dataset "ds" across the new defined grid

ds_z_new2 = ds2.interp(depth=z_new2, lon=lon_new2)


# Meshgrid the longitude and depth grid

Xgrid2, Ygrid2 = np.meshgrid(ds_z_new2['lon'], ds_z_new2['depth'])


# Define new temperature variable dimensions. We only want longitude and depth

ds_z_t_an2 = ds_z_new2['t_an'][0,:,:]


# Print the shapes to show how the grid changed the temperature data. Note that the shapes look transposed.
# This is because of the np.meshgrid() function.

print(f'Original Grid Shape VS New Grid Shape:\nOriginal temperature value shape: {t_an2.shape}\nGridded temperature value shape: {ds_z_t_an2.shape}')
# Out:
# Original Grid Shape VS New Grid Shape:
# Original temperature value shape: (47, 4)
# Gridded temperature value shape: (200, 48)

# %% [markdown]
# ## March

# %%
# Open WOA Climatology Dataset and Select the TH Line transect

ds3 = xr.open_dataset(r'C:\Users\marqjace\t_anom\woa_climatology_data\woa18_decav_t03_01.nc', decode_times=False)


# Select the extent of the TH Line 200km inshore (-126.5 to -123.5W longitude, 0-1000m depth)

ds3 = ds3.sel(lat=41.5, lon=slice(-126.5, -123.5), depth=slice(0,1000))


# Name the variables

t_an3 = ds3['t_an'][0,:,:]  # Temperature
lon3 = ds3['lon']  # Longitude
lat3 = ds3['lat']  # Latitude
depth3 = ds3['depth']  # Depth


# Define a new grid (112 points longitude, 200 points depth)

z_new3 = np.arange(0,1000, 5)
lon_new3 = np.arange(-126.5, -123.5, 0.0625)


# Linearly interpolate the dataset "ds" across the new defined grid

ds_z_new3 = ds3.interp(depth=z_new3, lon=lon_new3)


# Meshgrid the longitude and depth grid

Xgrid3, Ygrid3 = np.meshgrid(ds_z_new3['lon'], ds_z_new3['depth'])


# Define new temperature variable dimensions. We only want longitude and depth

ds_z_t_an3 = ds_z_new3['t_an'][0,:,:]


# Print the shapes to show how the grid changed the temperature data. Note that the shapes look transposed.
# This is because of the np.meshgrid() function.

print(f'Original Grid Shape VS New Grid Shape:\nOriginal temperature value shape: {t_an3.shape}\nGridded temperature value shape: {ds_z_t_an3.shape}')
# Out:
# Original Grid Shape VS New Grid Shape:
# Original temperature value shape: (47, 4)
# Gridded temperature value shape: (200, 48)

# %% [markdown]
# ## April

# %%
# Open WOA Climatology Dataset and Select the TH Line transect

ds4 = xr.open_dataset(r'C:\Users\marqjace\t_anom\woa_climatology_data\woa18_decav_t04_01.nc', decode_times=False)


# Select the extent of the TH Line 200km inshore (-126.5 to -123.5W longitude, 0-1000m depth)

ds4 = ds4.sel(lat=41.5, lon=slice(-126.5, -123.5), depth=slice(0,1000))


# Name the variables

t_an4 = ds4['t_an'][0,:,:]  # Temperature
lon4 = ds4['lon']  # Longitude
lat4 = ds4['lat']  # Latitude
depth4 = ds4['depth']  # Depth


# Define a new grid (112 points longitude, 200 points depth)

z_new4 = np.arange(0,1000, 5)
lon_new4 = np.arange(-126.5, -123.5, 0.0625)


# Linearly interpolate the dataset "ds" across the new defined grid

ds_z_new4 = ds4.interp(depth=z_new4, lon=lon_new4)


# Meshgrid the longitude and depth grid

Xgrid4, Ygrid4 = np.meshgrid(ds_z_new4['lon'], ds_z_new4['depth'])


# Define new temperature variable dimensions. We only want longitude and depth

ds_z_t_an4 = ds_z_new4['t_an'][0,:,:]


# Print the shapes to show how the grid changed the temperature data. Note that the shapes look transposed.
# This is because of the np.meshgrid() function.

print(f'Original Grid Shape VS New Grid Shape:\nOriginal temperature value shape: {t_an4.shape}\nGridded temperature value shape: {ds_z_t_an4.shape}')
# Out:
# Original Grid Shape VS New Grid Shape:
# Original temperature value shape: (47, 4)
# Gridded temperature value shape: (200, 48)

# %% [markdown]
# ## May

# %%
# Open WOA Climatology Dataset and Select the TH Line transect

ds5 = xr.open_dataset(r'C:\Users\marqjace\t_anom\woa_climatology_data\woa18_decav_t05_01.nc', decode_times=False)


# Select the extent of the TH Line 200km inshore (-126.5 to -123.5W longitude, 0-1000m depth)

ds5 = ds5.sel(lat=41.5, lon=slice(-126.5, -123.5), depth=slice(0,1000))


# Name the variables

t_an5 = ds5['t_an'][0,:,:]  # Temperature
lon5 = ds5['lon']  # Longitude
lat5 = ds5['lat']  # Latitude
depth5 = ds5['depth']  # Depth


# Define a new grid (112 points longitude, 200 points depth)

z_new5 = np.arange(0,1000, 5)
lon_new5 = np.arange(-126.5, -123.5, 0.0625)


# Linearly interpolate the dataset "ds" across the new defined grid

ds_z_new5 = ds5.interp(depth=z_new5, lon=lon_new5)


# Meshgrid the longitude and depth grid

Xgrid5, Ygrid5 = np.meshgrid(ds_z_new5['lon'], ds_z_new5['depth'])


# Define new temperature variable dimensions. We only want longitude and depth

ds_z_t_an5 = ds_z_new5['t_an'][0,:,:]


# Print the shapes to show how the grid changed the temperature data. Note that the shapes look transposed.
# This is because of the np.meshgrid() function.

print(f'Original Grid Shape VS New Grid Shape:\nOriginal temperature value shape: {t_an5.shape}\nGridded temperature value shape: {ds_z_t_an5.shape}')
# Out:
# Original Grid Shape VS New Grid Shape:
# Original temperature value shape: (47, 4)
# Gridded temperature value shape: (200, 48)

# %% [markdown]
# ## June

# %%
# Open WOA Climatology Dataset and Select the TH Line transect

ds6 = xr.open_dataset(r'C:\Users\marqjace\t_anom\woa_climatology_data\woa18_decav_t06_01.nc', decode_times=False)


# Select the extent of the TH Line 200km inshore (-126.5 to -123.5W longitude, 0-1000m depth)

ds6 = ds6.sel(lat=41.5, lon=slice(-126.5, -123.5), depth=slice(0,1000))


# Name the variables

t_an6 = ds6['t_an'][0,:,:]  # Temperature
lon6 = ds6['lon']  # Longitude
lat6 = ds6['lat']  # Latitude
depth6 = ds6['depth']  # Depth


# Define a new grid (112 points longitude, 200 points depth)

z_new6 = np.arange(0,1000, 5)
lon_new6 = np.arange(-126.5, -123.5, 0.0625)


# Linearly interpolate the dataset "ds" across the new defined grid

ds_z_new6 = ds6.interp(depth=z_new6, lon=lon_new6)


# Meshgrid the longitude and depth grid

Xgrid6, Ygrid6 = np.meshgrid(ds_z_new6['lon'], ds_z_new6['depth'])


# Define new temperature variable dimensions. We only want longitude and depth

ds_z_t_an6 = ds_z_new6['t_an'][0,:,:]


# Print the shapes to show how the grid changed the temperature data. Note that the shapes look transposed.
# This is because of the np.meshgrid() function.

print(f'Original Grid Shape VS New Grid Shape:\nOriginal temperature value shape: {t_an6.shape}\nGridded temperature value shape: {ds_z_t_an6.shape}')
# Out:
# Original Grid Shape VS New Grid Shape:
# Original temperature value shape: (47, 4)
# Gridded temperature value shape: (200, 48)

# %% [markdown]
# ## July

# %%
# Open WOA Climatology Dataset and Select the TH Line transect

ds7 = xr.open_dataset(r'C:\Users\marqjace\t_anom\woa_climatology_data\woa18_decav_t07_01.nc', decode_times=False)


# Select the extent of the TH Line 200km inshore (-126.5 to -123.5W longitude, 0-1000m depth)

ds7 = ds7.sel(lat=41.5, lon=slice(-126.5, -123.5), depth=slice(0,1000))


# Name the variables

t_an7 = ds7['t_an'][0,:,:]  # Temperature
lon7 = ds7['lon']  # Longitude
lat7 = ds7['lat']  # Latitude
depth7 = ds7['depth']  # Depth


# Define a new grid (112 points longitude, 200 points depth)

z_new7 = np.arange(0,1000, 5)
lon_new7 = np.arange(-126.5, -123.5, 0.0625)


# Linearly interpolate the dataset "ds" across the new defined grid

ds_z_new7 = ds7.interp(depth=z_new7, lon=lon_new7)


# Meshgrid the longitude and depth grid

Xgrid7, Ygrid7 = np.meshgrid(ds_z_new7['lon'], ds_z_new7['depth'])


# Define new temperature variable dimensions. We only want longitude and depth

ds_z_t_an7 = ds_z_new7['t_an'][0,:,:]


# Print the shapes to show how the grid changed the temperature data. Note that the shapes look transposed.
# This is because of the np.meshgrid() function.

print(f'Original Grid Shape VS New Grid Shape:\nOriginal temperature value shape: {t_an7.shape}\nGridded temperature value shape: {ds_z_t_an7.shape}')
# Out:
# Original Grid Shape VS New Grid Shape:
# Original temperature value shape: (47, 4)
# Gridded temperature value shape: (200, 48)

# %% [markdown]
# ## August

# %%
# Open WOA Climatology Dataset and Select the TH Line transect

ds8 = xr.open_dataset(r'C:\Users\marqjace\t_anom\woa_climatology_data\woa18_decav_t08_01.nc', decode_times=False)


# Select the extent of the TH Line 200km inshore (-126.5 to -123.5W longitude, 0-1000m depth)

ds8 = ds8.sel(lat=41.5, lon=slice(-126.5, -123.5), depth=slice(0,1000))


# Name the variables

t_an8 = ds8['t_an'][0,:,:]  # Temperature
lon8 = ds8['lon']  # Longitude
lat8 = ds8['lat']  # Latitude
depth8 = ds8['depth']  # Depth


# Define a new grid (112 points longitude, 200 points depth)

z_new8 = np.arange(0,1000, 5)
lon_new8 = np.arange(-126.5, -123.5, 0.0625)


# Linearly interpolate the dataset "ds" across the new defined grid

ds_z_new8 = ds8.interp(depth=z_new8, lon=lon_new8)


# Meshgrid the longitude and depth grid

Xgrid8, Ygrid8 = np.meshgrid(ds_z_new8['lon'], ds_z_new8['depth'])


# Define new temperature variable dimensions. We only want longitude and depth

ds_z_t_an8 = ds_z_new8['t_an'][0,:,:]


# Print the shapes to show how the grid changed the temperature data. Note that the shapes look transposed.
# This is because of the np.meshgrid() function.

print(f'Original Grid Shape VS New Grid Shape:\nOriginal temperature value shape: {t_an8.shape}\nGridded temperature value shape: {ds_z_t_an8.shape}')
# Out:
# Original Grid Shape VS New Grid Shape:
# Original temperature value shape: (47, 4)
# Gridded temperature value shape: (200, 48)

# %% [markdown]
# ## September

# %%
# Open WOA Climatology Dataset and Select the TH Line transect

ds9 = xr.open_dataset(r'C:\Users\marqjace\t_anom\woa_climatology_data\woa18_decav_t09_01.nc', decode_times=False)


# Select the extent of the TH Line 200km inshore (-126.5 to -123.5W longitude, 0-1000m depth)

ds9 = ds9.sel(lat=41.5, lon=slice(-126.5, -123.5), depth=slice(0,1000))


# Name the variables

t_an9 = ds9['t_an'][0,:,:]  # Temperature
lon9 = ds9['lon']  # Longitude
lat9 = ds9['lat']  # Latitude
depth9 = ds9['depth']  # Depth


# Define a new grid (112 points longitude, 200 points depth)

z_new9 = np.arange(0,1000, 5)
lon_new9 = np.arange(-126.5, -123.5, 0.0625)


# Linearly interpolate the dataset "ds" across the new defined grid

ds_z_new9 = ds9.interp(depth=z_new9, lon=lon_new9)


# Meshgrid the longitude and depth grid

Xgrid9, Ygrid9 = np.meshgrid(ds_z_new9['lon'], ds_z_new9['depth'])


# Define new temperature variable dimensions. We only want longitude and depth

ds_z_t_an9 = ds_z_new9['t_an'][0,:,:]


# Print the shapes to show how the grid changed the temperature data. Note that the shapes look transposed.
# This is because of the np.meshgrid() function.

print(f'Original Grid Shape VS New Grid Shape:\nOriginal temperature value shape: {t_an9.shape}\nGridded temperature value shape: {ds_z_t_an9.shape}')
# Out:
# Original Grid Shape VS New Grid Shape:
# Original temperature value shape: (47, 4)
# Gridded temperature value shape: (200, 48)

# %% [markdown]
# ## October

# %%
# Open WOA Climatology Dataset and Select the TH Line transect

ds10 = xr.open_dataset(r'C:\Users\marqjace\t_anom\woa_climatology_data\woa18_decav_t10_01.nc', decode_times=False)


# Select the extent of the TH Line 200km inshore (-126.5 to -123.5W longitude, 0-1000m depth)

ds10 = ds10.sel(lat=41.5, lon=slice(-126.5, -123.5), depth=slice(0,1000))


# Name the variables

t_an10 = ds10['t_an'][0,:,:]  # Temperature
lon10 = ds10['lon']  # Longitude
lat10 = ds10['lat']  # Latitude
depth10 = ds10['depth']  # Depth


# Define a new grid (112 points longitude, 200 points depth)

z_new10 = np.arange(0,1000, 5)
lon_new10 = np.arange(-126.5, -123.5, 0.0625)


# Linearly interpolate the dataset "ds" across the new defined grid

ds_z_new10 = ds10.interp(depth=z_new10, lon=lon_new10)


# Meshgrid the longitude and depth grid

Xgrid10, Ygrid10 = np.meshgrid(ds_z_new10['lon'], ds_z_new10['depth'])


# Define new temperature variable dimensions. We only want longitude and depth

ds_z_t_an10 = ds_z_new10['t_an'][0,:,:]


# Print the shapes to show how the grid changed the temperature data. Note that the shapes look transposed.
# This is because of the np.meshgrid() function.

print(f'Original Grid Shape VS New Grid Shape:\nOriginal temperature value shape: {t_an10.shape}\nGridded temperature value shape: {ds_z_t_an10.shape}')
# Out:
# Original Grid Shape VS New Grid Shape:
# Original temperature value shape: (47, 4)
# Gridded temperature value shape: (200, 48)

# %% [markdown]
# ## November

# %%
# Open WOA Climatology Dataset and Select the TH Line transect

ds11 = xr.open_dataset(r'C:\Users\marqjace\t_anom\woa_climatology_data\woa18_decav_t11_01.nc', decode_times=False)


# Select the extent of the TH Line 200km inshore (-126.5 to -123.5W longitude, 0-1000m depth)

ds11 = ds11.sel(lat=41.5, lon=slice(-126.5, -123.5), depth=slice(0,1000))


# Name the variables

t_an11 = ds11['t_an'][0,:,:]  # Temperature
lon11 = ds11['lon']  # Longitude
lat11 = ds11['lat']  # Latitude
depth11 = ds11['depth']  # Depth


# Define a new grid (112 points longitude, 200 points depth)

z_new11 = np.arange(0,1000, 5)
lon_new11 = np.arange(-126.5, -123.5, 0.0625)


# Linearly interpolate the dataset "ds" across the new defined grid

ds_z_new11 = ds11.interp(depth=z_new11, lon=lon_new11)


# Meshgrid the longitude and depth grid

Xgrid11, Ygrid11 = np.meshgrid(ds_z_new11['lon'], ds_z_new11['depth'])


# Define new temperature variable dimensions. We only want longitude and depth

ds_z_t_an11 = ds_z_new11['t_an'][0,:,:]


# Print the shapes to show how the grid changed the temperature data. Note that the shapes look transposed.
# This is because of the np.meshgrid() function.

print(f'Original Grid Shape VS New Grid Shape:\nOriginal temperature value shape: {t_an11.shape}\nGridded temperature value shape: {ds_z_t_an11.shape}')
# Out:
# Original Grid Shape VS New Grid Shape:
# Original temperature value shape: (47, 4)
# Gridded temperature value shape: (200, 48)

# %% [markdown]
# ## December

# %%
# Open WOA Climatology Dataset and Select the TH Line transect

ds12 = xr.open_dataset(r'C:\Users\marqjace\t_anom\woa_climatology_data\woa18_decav_t12_01.nc', decode_times=False)


# Select the extent of the TH Line 200km inshore (-126.5 to -123.5W longitude, 0-1000m depth)

ds12 = ds12.sel(lat=41.5, lon=slice(-126.5, -123.5), depth=slice(0,1000))


# Name the variables

t_an12 = ds12['t_an'][0,:,:]  # Temperature
lon12 = ds12['lon']  # Longitude
lat12 = ds12['lat']  # Latitude
depth12 = ds12['depth']  # Depth


# Define a new grid (112 points longitude, 200 points depth)

z_new12 = np.arange(0,1000, 5)
lon_new12 = np.arange(-126.5, -123.5, 0.0625)


# Linearly interpolate the dataset "ds" across the new defined grid

ds_z_new12 = ds12.interp(depth=z_new12, lon=lon_new12)


# Meshgrid the longitude and depth grid

Xgrid12, Ygrid12 = np.meshgrid(ds_z_new12['lon'], ds_z_new12['depth'])


# Define new temperature variable dimensions. We only want longitude and depth

ds_z_t_an12 = ds_z_new12['t_an'][0,:,:]


# Print the shapes to show how the grid changed the temperature data. Note that the shapes look transposed.
# This is because of the np.meshgrid() function.

print(f'Original Grid Shape VS New Grid Shape:\nOriginal temperature value shape: {t_an12.shape}\nGridded temperature value shape: {ds_z_t_an12.shape}')
# Out:
# Original Grid Shape VS New Grid Shape:
# Original temperature value shape: (47, 4)
# Gridded temperature value shape: (200, 48)

# %% [markdown]
# # Glider Transect Data

# %% [markdown]
# ## New Grid

# %%
# Set up new grid (48 points is 3 deg longitude for every 5 km, 200 points depth to 1000m is every 5 meters)


# number of grid points:

xn, yn = 48, 200


# grid window

xmin, xmax = -126.5, -123.5
ymin, ymax = 0, 1000


# Generate a regular grid to interpolate the data

xgrid = np.linspace(xmin, xmax, xn)
ygrid = np.linspace(ymin, ymax, yn)
Xgrid, Ygrid = np.meshgrid(xgrid, ygrid)

# %% [markdown]
# ## Sep 19 Deployment

# %% [markdown]
# ### Transect 1 Sep 19

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/sep_2019/transect1/p157*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_9_19 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/sep_2019/transect1\p1570064.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 126/126 [00:00<00:00, 270.30it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 83097)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2019-09-16T17:59:33 ... 201...
#     depth          (sg_data_point) float64 0.3571 0.3949 ... 0.606 0.03814
#     longitude      (sg_data_point) float64 -124.4 -124.4 ... -130.0 -130.0
#     latitude       (sg_data_point) float64 40.85 40.85 40.85 ... 41.08 41.08
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... 32.65 nan nan nan
# ...

# %% [markdown]
# ### Transect 2 Oct 19

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/sep_2019/transect2/p157*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_10_19 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/sep_2019/transect2\p1570195.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 132/132 [00:00<00:00, 232.26it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 89978)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2019-10-13T21:07:27 ... 201...
#     depth          (sg_data_point) float64 0.9977 0.9538 1.224 ... 0.1589 0.1561
#     longitude      (sg_data_point) float64 -130.0 -130.0 ... -124.3 -124.3
#     latitude       (sg_data_point) float64 41.08 41.08 41.08 ... 41.06 41.06
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... 32.75 nan nan nan
# ...

# %% [markdown]
# ### Transect 3 Nov 19

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/sep_2019/transect3/p157*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_11_19 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/sep_2019/transect3\p1570309.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 97/97 [00:00<00:00, 121.79it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 68215)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2019-11-13T05:35:37 ... 201...
#     depth          (sg_data_point) float64 0.6346 0.714 0.9362 ... 0.9729 0.4444
#     longitude      (sg_data_point) float64 -124.3 -124.3 ... -130.0 -130.0
#     latitude       (sg_data_point) float64 41.06 41.06 41.06 ... 41.08 41.08
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... 32.65 32.65 nan
# ...

# %% [markdown]
# ### Transect 4 Dec 19

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/sep_2019/transect4/p157*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_12_19 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/sep_2019/transect4\p1570411.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 107/107 [00:00<00:00, 125.83it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 77248)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2019-12-06T06:38:01 ... 202...
#     depth          (sg_data_point) float64 0.3826 0.4212 0.3096 ... 185.7 185.7
#     longitude      (sg_data_point) float64 -130.0 -130.0 ... -124.4 -124.4
#     latitude       (sg_data_point) float64 41.08 41.08 41.08 ... 41.06 41.06
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... nan nan nan nan
# ...

# %% [markdown]
# ### Transect 5 Jan 20

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/sep_2019/transect5/p157*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_1_20 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/sep_2019/transect5\p1570522.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 115/115 [00:00<00:00, 271.40it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 83321)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2020-01-02T06:38:25 ... 202...
#     depth          (sg_data_point) float64 0.6674 0.6852 ... 0.1364 0.08924
#     longitude      (sg_data_point) float64 -124.4 -124.4 ... -130.0 -130.0
#     latitude       (sg_data_point) float64 41.06 41.06 41.06 ... 41.06 41.06
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... 32.51 nan nan nan
# ...

# %% [markdown]
# ### Transect 6 Feb 20

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/sep_2019/transect6/p157*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_2_20 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/sep_2019/transect6\p1570637.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 114/114 [00:00<00:00, 264.59it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 83314)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2020-01-31T23:54:51 ... 202...
#     depth          (sg_data_point) float64 0.5494 0.409 0.6712 ... 0.1361 0.157
#     longitude      (sg_data_point) float64 -130.0 -130.0 ... -124.4 -124.4
#     latitude       (sg_data_point) float64 41.06 41.06 41.06 ... 41.05 41.05
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... nan nan nan nan
# ...

# %% [markdown]
# ### Transect 7 Mar 20

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/sep_2019/transect7/p157*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_3_20_a = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/sep_2019/transect7\p1570708.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 29/29 [00:00<00:00, 267.05it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 19471)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2020-03-02T11:14:35 ... 202...
#     depth          (sg_data_point) float64 0.5528 0.4575 ... 0.6626 0.01438
#     longitude      (sg_data_point) float64 -124.4 -124.4 ... -125.8 -125.8
#     latitude       (sg_data_point) float64 41.05 41.05 41.05 ... 41.07 41.07
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... 32.61 32.6 nan
# ...

# %% [markdown]
# ### Transect 8 Mar 20

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/sep_2019/transect8/p157*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_3_20_b = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/sep_2019/transect8\p1570756.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 66/66 [00:00<00:00, 278.01it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 38659)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2020-03-08T21:44:20 ... 202...
#     depth          (sg_data_point) float64 0.4129 0.4562 ... 0.06305 0.07013
#     longitude      (sg_data_point) float64 -125.8 -125.8 ... -124.4 -124.4
#     latitude       (sg_data_point) float64 41.07 41.07 41.07 ... 40.89 40.89
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... nan nan nan nan
# ...

# %% [markdown]
# ## Sep 20 Deployment

# %% [markdown]
# ### Transect 1 Sep 20

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/sep_2020/transect1/p157*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_9_20 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/sep_2020/transect1\p1570062.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 123/123 [00:00<00:00, 274.05it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 84765)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2020-09-16T18:59:17 ... 202...
#     depth          (sg_data_point) float64 0.3603 0.3488 ... 0.2164 -0.2286
#     longitude      (sg_data_point) float64 -124.4 -124.4 ... -129.1 -129.1
#     latitude       (sg_data_point) float64 40.85 40.85 40.85 ... 41.07 41.07
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... 32.2 nan nan
# ...

# %% [markdown]
# ### Transect 2 Oct 20

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/sep_2020/transect2/p157*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_10_20 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/sep_2020/transect2\p1570178.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 108/108 [00:00<00:00, 268.42it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 75523)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2020-10-12T19:13:58 ... 202...
#     depth          (sg_data_point) float64 0.4548 0.4966 ... 0.5663 0.09692
#     longitude      (sg_data_point) float64 -129.1 -129.1 ... -124.3 -124.3
#     latitude       (sg_data_point) float64 41.07 41.07 41.07 ... 41.06 41.06
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... 33.62 33.62 nan
# ...

# %% [markdown]
# ### Transect 3 Nov 20

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/sep_2020/transect3/p157*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_11_20 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/sep_2020/transect3\p1570284.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 105/105 [00:00<00:00, 127.91it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 73930)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2020-11-06T05:47:15 ... 202...
#     depth          (sg_data_point) float64 0.2971 0.2217 ... -0.1337 -0.05869
#     longitude      (sg_data_point) float64 -124.3 -124.3 ... -129.0 -129.0
#     latitude       (sg_data_point) float64 41.06 41.06 41.06 ... 41.05 41.05
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... nan nan nan nan
# ...

# %% [markdown]
# ### Transect 4 Dec 20

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/sep_2020/transect4/p157*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_12_20 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/sep_2020/transect4\p1570396.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 119/119 [00:00<00:00, 238.94it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 89437)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2020-12-01T01:24:42 ... 202...
#     depth          (sg_data_point) float64 0.4957 0.5543 ... 0.2985 -0.1107
#     longitude      (sg_data_point) float64 -129.0 -129.0 ... -124.4 -124.4
#     latitude       (sg_data_point) float64 41.05 41.05 41.05 ... 41.06 41.06
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... 32.79 nan nan
# ...

# %% [markdown]
# ### Transect 5 Jan 21

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/sep_2020/transect5/p157*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_1_21 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/sep_2020/transect5\p1570498.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 85/85 [00:00<00:00, 261.12it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 63226)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2020-12-31T22:53:26 ... 202...
#     depth          (sg_data_point) float64 0.4093 0.6169 0.5646 ... 1.118 0.4934
#     longitude      (sg_data_point) float64 -124.4 -124.4 ... -129.0 -129.0
#     latitude       (sg_data_point) float64 41.06 41.06 41.06 ... 41.07 41.07
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... 32.37 32.37 nan
# ...

# %% [markdown]
# ### Transect 6 Feb 21

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/sep_2020/transect6/p157*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_2_21 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/sep_2020/transect6\p1570569.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 56/56 [00:00<00:00, 122.65it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 41627)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2021-01-22T04:55:02 ... 202...
#     depth          (sg_data_point) float64 0.5026 0.5786 ... -0.09669 -0.1166
#     longitude      (sg_data_point) float64 -129.0 -129.0 ... -126.9 -126.9
#     latitude       (sg_data_point) float64 41.07 41.07 41.07 ... 41.05 41.05
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... nan nan nan nan
# ...

# %% [markdown]
# ## Nov 21 Deployment

# %% [markdown]
# ### Transect 1 Nov 21

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/nov_2021/transect1/p646*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_11_21 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/nov_2021/transect1\p6460078.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 155/155 [00:01<00:00, 126.69it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 108100)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2021-11-12T18:49:01 ... 202...
#     depth          (sg_data_point) float64 0.4598 0.5845 0.6586 ... 1.356 0.3756
#     longitude      (sg_data_point) float64 -124.4 -124.4 ... -128.4 -128.4
#     latitude       (sg_data_point) float64 40.85 40.85 40.85 ... 40.93 40.93
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... 32.39 32.39 nan
# ...

# %% [markdown]
# ### Transect 2 Dec 21

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/nov_2021/transect2/p646*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_12_21 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/nov_2021/transect2\p6460209.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 107/107 [00:00<00:00, 221.70it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 78715)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2021-12-16T00:22:19 ... 202...
#     depth          (sg_data_point) float64 0.3813 0.4589 ... 0.2123 -0.02479
#     longitude      (sg_data_point) float64 -128.4 -128.4 ... -124.4 -124.4
#     latitude       (sg_data_point) float64 40.93 40.93 40.93 ... 41.1 41.1 41.1
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... 32.48 nan nan
# ...

# %% [markdown]
# ### Transect 3 Jan 22

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/nov_2021/transect3/p646*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_1_22 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/nov_2021/transect3\p6460334.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 143/143 [00:00<00:00, 246.38it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 129832)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2022-01-08T06:24:32 ... 202...
#     depth          (sg_data_point) float64 0.4164 0.4443 ... 0.3042 -0.01376
#     longitude      (sg_data_point) float64 -124.4 -124.4 ... -129.0 -129.0
#     latitude       (sg_data_point) float64 41.1 41.1 41.1 ... 41.05 41.05 41.05
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... 32.5 32.5 nan nan
# ...

# %% [markdown]
# ### Transect 4 Feb 22

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/nov_2021/transect4/p646*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_2_22 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/nov_2021/transect4\p6460453.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 94/94 [00:00<00:00, 249.03it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 87890)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2022-02-10T21:34:28 ... 202...
#     depth          (sg_data_point) float64 0.4453 0.4751 ... -0.05336 -0.2336
#     longitude      (sg_data_point) float64 -129.0 -129.0 ... -124.4 -124.4
#     latitude       (sg_data_point) float64 41.05 41.05 41.05 ... 41.05 41.05
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... 33.36 nan nan nan
# ...

# %% [markdown]
# ### Transect 5 Mar 22

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/nov_2021/transect5/p646*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_3_22 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/nov_2021/transect5\p6460600.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 201/201 [00:00<00:00, 269.34it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 196809)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2022-03-04T09:40:05 ... 202...
#     depth          (sg_data_point) float64 0.2398 0.2854 ... 0.4906 -0.05536
#     longitude      (sg_data_point) float64 -124.4 -124.4 ... -129.0 -129.0
#     latitude       (sg_data_point) float64 41.05 41.05 41.05 ... 41.06 41.06
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... 32.51 nan nan
# ...

# %% [markdown]
# ### Transect 6 Apr 22

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/nov_2021/transect6/p646*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_4_22 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/nov_2021/transect6\p6460745.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 89/89 [00:00<00:00, 215.79it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 88504)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2022-04-23T11:23:51 ... 202...
#     depth          (sg_data_point) float64 0.5343 0.5861 0.6974 ... 0.751 0.4341
#     longitude      (sg_data_point) float64 -129.0 -129.0 ... -124.4 -124.4
#     latitude       (sg_data_point) float64 41.06 41.06 41.06 ... 41.04 41.04
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... 31.97 31.98 nan
# ...

# %% [markdown]
# ### Transect 7 May 22

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/nov_2021/transect7/p646*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_5_22 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/nov_2021/transect7\p6460833.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 87/87 [00:00<00:00, 263.66it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 84801)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2022-05-14T20:25:49 ... 202...
#     depth          (sg_data_point) float64 0.5448 0.5343 0.6043 ... 1.136 0.3663
#     longitude      (sg_data_point) float64 -124.4 -124.4 ... -126.8 -126.8
#     latitude       (sg_data_point) float64 41.04 41.04 41.04 ... 41.05 41.05
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... 32.33 32.33 nan
# ...

# %% [markdown]
# ### Transect 8 Jun 22

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/nov_2021/transect8/p646*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_6_22 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/nov_2021/transect8\p6460910.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 67/67 [00:00<00:00, 274.06it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 60795)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2022-06-03T20:34:27 ... 202...
#     depth          (sg_data_point) float64 0.5231 0.4347 ... 0.5939 0.2834
#     longitude      (sg_data_point) float64 -126.8 -126.8 ... -124.4 -124.4
#     latitude       (sg_data_point) float64 41.05 41.05 41.05 ... 40.82 40.82
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... 31.89 31.87 nan
# ...

# %% [markdown]
# ## Jul 22 Deployment

# %% [markdown]
# ### Transect 1 Aug 22

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/jul_2022/transect1/p646*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_8_22 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/jul_2022/transect1\p6460073.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 145/145 [00:00<00:00, 242.19it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 269631)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2022-07-29T04:16:04 ... 202...
#     depth          (sg_data_point) float64 0.4072 0.3451 0.4119 ... 25.27 25.3
#     longitude      (sg_data_point) float64 -124.5 -124.5 ... -129.1 -129.1
#     latitude       (sg_data_point) float64 40.85 40.85 40.85 ... 41.05 41.05
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... 32.46 nan nan nan
# ...

# %% [markdown]
# ### Transect 2 Sep 22

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/jul_2022/transect2/p646*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_9_22 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/jul_2022/transect2\p6460232.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 172/172 [00:00<00:00, 242.90it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 335295)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2022-08-27T00:25:40 ... 202...
#     depth          (sg_data_point) float64 0.3015 0.3634 ... -0.3273 -0.3294
#     longitude      (sg_data_point) float64 -129.1 -129.1 ... -124.4 -124.4
#     latitude       (sg_data_point) float64 41.05 41.05 41.05 ... 41.06 41.06
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... nan nan nan nan
# ...

# %% [markdown]
# ### Transect 3 Oct 22

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/jul_2022/transect3/p646*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_10_22 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/jul_2022/transect3\p6460412.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 189/189 [00:00<00:00, 240.96it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 348449)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2022-10-01T13:39:49 ... 202...
#     depth          (sg_data_point) float64 0.724 0.764 0.8839 ... 1.102 0.5753
#     longitude      (sg_data_point) float64 -124.4 -124.4 ... -129.0 -129.0
#     latitude       (sg_data_point) float64 41.06 41.06 41.06 ... 41.05 41.05
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... 32.25 32.25 nan
# ...

# %% [markdown]
# ### Transect 4 Nov 22

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/jul_2022/transect4/p646*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_11_22 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/jul_2022/transect4\p6460555.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 97/97 [00:00<00:00, 240.39it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 163985)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2022-11-14T02:19:18 ... 202...
#     depth          (sg_data_point) float64 0.5879 0.5681 0.6255 ... 178.8 178.7
#     longitude      (sg_data_point) float64 -129.0 -129.0 ... -124.4 -124.4
#     latitude       (sg_data_point) float64 41.05 41.05 41.05 ... 41.07 41.07
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... nan nan nan nan
# ...

# %% [markdown]
# ### Transect 5 Dec 22

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/jul_2022/transect5/p646*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_12_22 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/jul_2022/transect5\p6460661.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 115/115 [00:00<00:00, 247.15it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 194281)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2022-12-07T18:21:16 ... 202...
#     depth          (sg_data_point) float64 0.3271 0.4422 ... 0.7228 0.1099
#     longitude      (sg_data_point) float64 -124.4 -124.4 ... -127.8 -127.8
#     latitude       (sg_data_point) float64 41.07 41.07 41.07 ... 41.06 41.06
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... 32.34 32.33 nan
# ...

# %% [markdown]
# ### Transect 6 Jan 23

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/jul_2022/transect6/p646*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_1_23 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/jul_2022/transect6\p6460772.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 107/107 [00:00<00:00, 193.62it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 163563)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2023-01-04T23:35:26 ... 202...
#     depth          (sg_data_point) float64 0.3427 0.06965 ... 41.36 41.3
#     longitude      (sg_data_point) float64 -127.8 -127.8 ... -124.4 -124.4
#     latitude       (sg_data_point) float64 41.06 41.06 41.06 ... 40.84 40.84
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... nan 32.29 nan nan
# ...

# %% [markdown]
# ## Jan 23 Deployment

# %% [markdown]
# ### Transect 1 Feb 23

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/jan_2023/transect1/p685*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_2_23 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/jan_2023/transect1\p6850059.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 117/117 [00:00<00:00, 248.29it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 186965)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2023-01-26T20:06:39 ... 202...
#     depth          (sg_data_point) float64 0.9907 0.9497 ... 0.1919 -0.06654
#     longitude      (sg_data_point) float64 -124.4 -124.4 ... -129.0 -129.0
#     latitude       (sg_data_point) float64 40.83 40.83 40.83 ... 41.07 41.07
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... 32.46 nan nan nan
# ...

# %% [markdown]
# ### Transect 2 Mar 23

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/jan_2023/transect2/p685*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_3_23_a = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/jan_2023/transect2\p6850168.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 101/101 [00:00<00:00, 245.26it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 167579)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2023-02-22T00:10:54 ... 202...
#     depth          (sg_data_point) float64 1.015 1.074 1.156 ... 0.1033 0.04072
#     longitude      (sg_data_point) float64 -129.0 -129.0 ... -124.3 -124.3
#     latitude       (sg_data_point) float64 41.06 41.06 41.06 ... 41.06 41.06
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... 31.89 nan nan nan
# ...

# %% [markdown]
# ### Transect 3 Mar 23

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/jan_2023/transect3/p685*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_3_23_b = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/jan_2023/transect3\p6850272.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 107/107 [00:00<00:00, 250.03it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 179882)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2023-03-17T14:57:21 ... 202...
#     depth          (sg_data_point) float64 0.8146 0.8352 ... 0.1864 -0.02827
#     longitude      (sg_data_point) float64 -124.3 -124.3 ... -129.1 -129.1
#     latitude       (sg_data_point) float64 41.06 41.06 41.06 ... 41.09 41.09
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... 32.54 nan nan nan
# ...

# %% [markdown]
# ### Transect 4 Apr 23

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/jan_2023/transect4/p685*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_4_23 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/jan_2023/transect4\p6850387.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 123/123 [00:00<00:00, 206.29it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 203788)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2023-04-12T02:02:49 ... 202...
#     depth          (sg_data_point) float64 0.8849 0.7605 ... -0.03677 -0.003807
#     longitude      (sg_data_point) float64 -129.1 -129.1 ... -124.4 -124.4
#     latitude       (sg_data_point) float64 41.09 41.09 41.09 ... 41.09 41.09
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... 31.9 nan nan nan
# ...

# %% [markdown]
# ### Transect 5 May 23

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/jan_2023/transect5/p685*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_5_23 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/jan_2023/transect5\p6850498.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 99/99 [00:00<00:00, 182.62it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 167826)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2023-05-10T18:03:26 ... 202...
#     depth          (sg_data_point) float64 1.02 0.9985 1.153 ... 0.2166 -0.05958
#     longitude      (sg_data_point) float64 -124.4 -124.4 ... -129.2 -129.2
#     latitude       (sg_data_point) float64 41.09 41.09 41.09 ... 41.07 41.07
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... 32.53 nan nan
# ...

# %% [markdown]
# ### Transect 6 June 23

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/jan_2023/transect6/p685*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_6_23 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/jan_2023/transect6\p6850622.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 148/148 [00:00<00:00, 210.83it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 242860)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2023-06-03T10:27:20 ... 202...
#     depth          (sg_data_point) float64 0.8242 0.8542 1.094 ... 0.6688 0.312
#     longitude      (sg_data_point) float64 -129.2 -129.2 ... -124.4 -124.4
#     latitude       (sg_data_point) float64 41.07 41.07 41.07 ... 41.08 41.08
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... 33.2 33.19 nan
# ...

# %% [markdown]
# ### Transect 7 Jul 23

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/jan_2023/transect7/p685*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_7_23 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/jan_2023/transect7\p6850732.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 73/73 [00:00<00:00, 238.98it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 116982)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2023-07-08T17:58:38 ... 202...
#     depth          (sg_data_point) float64 0.5962 0.628 ... -0.2024 -0.1786
#     longitude      (sg_data_point) float64 -124.4 -124.4 ... -127.2 -127.2
#     latitude       (sg_data_point) float64 41.08 41.08 41.08 ... 41.05 41.05
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... nan nan nan nan
# ...

# %% [markdown]
# ### Transect 8 Aug 23

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/jan_2023/transect8/p685*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_8_23 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/jan_2023/transect8\p6850820.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 103/103 [00:00<00:00, 250.56it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 162466)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2023-07-24T21:37:05 ... 202...
#     depth          (sg_data_point) float64 0.8577 0.9416 1.104 ... 0.08801 0.103
#     longitude      (sg_data_point) float64 -127.2 -127.2 ... -124.4 -124.4
#     latitude       (sg_data_point) float64 41.04 41.04 41.04 ... 41.2 41.2 41.2
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... 33.2 nan nan nan
# ...

# %% [markdown]
# ## Oct 23 Deployment

# %% [markdown]
# ### Transect 1 Oct 23

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/oct_2023/transect1/p685*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_10_23 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/oct_2023/transect1\p6850140.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 53/53 [00:00<00:00, 255.93it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 79938)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2023-11-05T19:21:32 ... 202...
#     depth          (sg_data_point) float64 0.5656 0.6659 ... -0.06155 0.01443
#     longitude      (sg_data_point) float64 -126.7 -126.7 ... -124.4 -124.4
#     latitude       (sg_data_point) float64 41.06 41.06 41.06 ... 41.07 41.07
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... nan nan nan nan
# ...

# %% [markdown]
# ### Transect 2 Nov 23

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/oct_2023/transect2/p685*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_11_23 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/oct_2023/transect2\p6850222.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 110/110 [00:00<00:00, 221.58it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 170947)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2023-11-16T19:54:27 ... 202...
#     depth          (sg_data_point) float64 0.695 0.7752 ... -0.03567 0.06551
#     longitude      (sg_data_point) float64 -124.4 -124.4 ... -127.5 -127.5
#     latitude       (sg_data_point) float64 41.07 41.07 41.07 ... 40.96 40.96
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... 32.58 nan nan nan
# ...

# %% [markdown]
# ### Transect 3 Dec 23

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/oct_2023/transect3/p685*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_12_23 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/oct_2023/transect3\p6850317.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 80/80 [00:00<00:00, 219.66it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 122191)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2023-12-11T07:35:30 ... 202...
#     depth          (sg_data_point) float64 0.8646 1.004 0.9837 ... 0.1486 0.1342
#     longitude      (sg_data_point) float64 -127.5 -127.5 ... -124.4 -124.4
#     latitude       (sg_data_point) float64 40.96 40.96 40.96 ... 41.06 41.06
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... nan nan nan nan
# ...

# %% [markdown]
# ### Transect 4 Jan 24

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/oct_2023/transect4/p685*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_1_24 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/oct_2023/transect4\p6850416.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 119/119 [00:00<00:00, 254.28it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 187172)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2023-12-28T16:46:12 ... 202...
#     depth          (sg_data_point) float64 1.106 0.8684 ... -0.06161 -0.09897
#     longitude      (sg_data_point) float64 -124.4 -124.4 ... -128.5 -128.5
#     latitude       (sg_data_point) float64 41.06 41.06 41.06 ... 41.02 41.02
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... 32.53 nan nan nan
# ...

# %% [markdown]
# ### Transect 5 Feb 24

# %%
# Open 
filenames = 'C:/Users/marqjace/t_anom/individual_dives/oct_2023/transect5/p685*.nc'

gt.load.seaglider_show_variables(filenames)

names = [
    'ctd_depth',
    'ctd_time',
    'ctd_pressure',
    'salinity',
    'temperature',
]

ds_dict = gt.load.seaglider_basestation_netCDFs(
    filenames, names,
    return_merged=True,
    keep_global_attrs=False
)

print(ds_dict.keys())

sg_data_point = ds_dict['sg_data_point']

dat = sg_data_point.rename({
    'salinity': 'salt_raw',
    'temperature': 'temp_raw',
    'ctd_pressure': 'pressure',
    'ctd_depth': 'depth',
    'ctd_time': 'time_raw',
})

print(dat)

# variable assignment for conveniant access
depth = dat.depth
dives = dat.dives
latitude = dat.latitude
longitude = dat.longitude
pres = dat.pressure
temp = dat.temp_raw
salt = dat.salt_raw


# Interpolate using "linear" method

Z_2_24 = griddata(points = (longitude, depth),
              values = temp,
              xi = (Xgrid, Ygrid),
              method = 'linear')
# Out:
# information is based on file: C:/Users/marqjace/t_anom/individual_dives/oct_2023/transect5\p6850521.nc
#
# DIMENSION: sg_data_point
# {salinity, ctd_pressure, temperature, ctd_depth, ctd_time, longitude, latitude}
# 100%|██████████| 91/91 [00:00<00:00, 253.73it/s]
# Cannot merge data - not enough time indexed DataFrames
# Returning unmerged dataframes
# dict_keys(['sg_data_point'])
# <xarray.Dataset>
# Dimensions:        (sg_data_point: 141198)
# Coordinates:
#     ctd_time_dt64  (sg_data_point) datetime64[ns] 2024-01-24T18:00:16 ... 202...
#     depth          (sg_data_point) float64 0.6192 0.6956 ... 0.00212 0.04831
#     longitude      (sg_data_point) float64 -128.5 -128.5 ... -124.4 -124.4
#     latitude       (sg_data_point) float64 41.02 41.02 41.02 ... 41.05 41.05
# Dimensions without coordinates: sg_data_point
# Data variables:
#     salt_raw       (sg_data_point) float64 nan nan nan nan ... nan nan nan nan
# ...

# %% [markdown]
# # Temperature Anomaly

# %% [markdown]
# ## By Transect

# %%
# Create Temperature Anomaly Array For Each Transect Line

# Sep 2019 Deployment
t_anom_9_19 = np.subtract(Z_9_19, ds_z_t_an9) # Transect 1 Sep 2019
t_anom_10_19 = np.subtract(Z_10_19, ds_z_t_an10) # Transect 2 Oct 2019
t_anom_11_19 = np.subtract(Z_11_19, ds_z_t_an11) # Transect 3 Nov 2019
t_anom_12_19 = np.subtract(Z_12_19, ds_z_t_an12) # Transect 4 Dec 2019
t_anom_1_20 = np.subtract(Z_1_20, ds_z_t_an1) # Transect 5 Jan 2020
t_anom_2_20 = np.subtract(Z_2_20, ds_z_t_an2) # Transect 6 Feb 2020
t_anom_3_20_a = np.subtract(Z_3_20_a, ds_z_t_an3) # Transect 7 Mar 2020
t_anom_3_20_b = np.subtract(Z_3_20_b, ds_z_t_an3) # Transect 8 Mar 2020

# Sep 2020 Deployment
t_anom_9_20 = np.subtract(Z_9_20, ds_z_t_an9) # Transect 1 Sep 2020
t_anom_10_20 = np.subtract(Z_10_20, ds_z_t_an10) # Transect 2 Oct 2020
t_anom_11_20 = np.subtract(Z_11_20, ds_z_t_an11) # Transect 3 Nov 2020
t_anom_12_20 = np.subtract(Z_12_20, ds_z_t_an12) # Transect 4 Dec 2020
t_anom_1_21 = np.subtract(Z_1_21, ds_z_t_an1) # Transect 5 Jan 2021
t_anom_2_21 = np.subtract(Z_2_21, ds_z_t_an2) # Transect 6 Feb 2021

# Nov 2021 Deployment
t_anom_11_21 = np.subtract(Z_11_21, ds_z_t_an11) # Transect 1 Nov 2021
t_anom_12_21 = np.subtract(Z_12_21, ds_z_t_an12) # Transect 2 Dec 2021
t_anom_1_22 = np.subtract(Z_1_22, ds_z_t_an1) # Transect 3 Jan 2022
t_anom_2_22 = np.subtract(Z_2_22, ds_z_t_an2) # Transect 4 Feb 2022
t_anom_3_22 = np.subtract(Z_3_22, ds_z_t_an3) # Transect 5 Mar 2022
t_anom_4_22 = np.subtract(Z_4_22, ds_z_t_an4) # Transect 6 Apr 2022
t_anom_5_22 = np.subtract(Z_5_22, ds_z_t_an5) # Transect 7 May 2022
t_anom_6_22 = np.subtract(Z_6_22, ds_z_t_an6) # Transect 8 Jun 2022

# Jul 2022 Deployment
t_anom_8_22 = np.subtract(Z_8_22, ds_z_t_an8) # Transect 1 Aug 2022
t_anom_9_22 = np.subtract(Z_9_22, ds_z_t_an9) # Transect 2 Sep 2022
t_anom_10_22 = np.subtract(Z_10_22, ds_z_t_an10) # Transect 3 Oct 2022
t_anom_11_22 = np.subtract(Z_11_22, ds_z_t_an11) # Transect 4 Nov 2022
t_anom_12_22 = np.subtract(Z_12_22, ds_z_t_an12) # Transect 5 Dec 2022
t_anom_1_23 = np.subtract(Z_1_23, ds_z_t_an1) # Transect 6 Jan 2023

# Jan 2023 Deployment
t_anom_2_23 = np.subtract(Z_2_23, ds_z_t_an2) # Transect 1 Feb 2023
t_anom_3_23_a = np.subtract(Z_3_23_a, ds_z_t_an3) # Transect 2 Mar 2023
t_anom_3_23_b = np.subtract(Z_3_23_b, ds_z_t_an3) # Transect 3 Mar 2023
t_anom_4_23 = np.subtract(Z_4_23, ds_z_t_an4) # Transect 4 Apr 2023
t_anom_5_23 = np.subtract(Z_5_23, ds_z_t_an5) # Transect 5 May 2023
t_anom_6_23 = np.subtract(Z_6_23, ds_z_t_an6) # Transect 6 Jun 2023
t_anom_7_23 = np.subtract(Z_7_23, ds_z_t_an7) # Transect 7 Jul 2023
t_anom_8_23 = np.subtract(Z_8_23, ds_z_t_an8) # Transect 8 Aug 2023

# Oct 2023 Deployment
t_anom_10_23 = np.subtract(Z_10_23, ds_z_t_an10) # Transect 1 Oct 2023
t_anom_11_23 = np.subtract(Z_11_23, ds_z_t_an11) # Transect 2 Nov 2023
t_anom_12_23 = np.subtract(Z_12_23, ds_z_t_an12) # Transect 3 Dec 2023
t_anom_1_24 = np.subtract(Z_1_24, ds_z_t_an1) # Transect 4 Jan 2024
t_anom_2_24 = np.subtract(Z_2_24, ds_z_t_an2) # Transect 4 Jan 2024

# %% [markdown]
# ### Plot Temp Anomaly

# %%
divnorm=colors.TwoSlopeNorm(vcenter=0., vmin=-4, vmax=4)

# Set up figure

fig, ax = plt.subplots(4, 2, figsize=(15,15), dpi=300)
plt.subplots_adjust(hspace=0.3)

# First TH Line Transect 01-26-23 - 02-21-23

# Raw Data
contour1 = ax[0,0].contourf(Xgrid, Ygrid, Z_2_23, cmap='jet')
ax[0,0].invert_yaxis()
ax[0,0].set_xlim(-129, -124)
ax[0,0].set_title('First TH Line Transect 01-26-23 - 02-21-23')
ax[0,0].set_ylabel('Depth (m)')
plt.colorbar(contour1, label=r'Temperature ($\degree$C)')

# Temp Anomaly
contour1b = ax[1,0].contourf(Xgrid, Ygrid, t_anom_2_23, cmap='RdYlBu_r', norm=divnorm)
ax[1,0].invert_yaxis()
ax[1,0].set_xlim(-129, -124)
ax[1,0].set_title('Temperature Anomaly')
ax[1,0].set_xlabel(r'Longitude ($\degree$E)')
ax[1,0].set_ylabel('Depth (m)')
plt.colorbar(contour1b, label=r'Temperature ($\degree$C)')


# Last TH Line Transect 07-25-23 - 08-14-23

# Raw Data
contour2 = ax[0,1].contourf(Xgrid, Ygrid, Z_8_23, cmap='jet')
ax[0,1].invert_yaxis()
ax[0,1].set_xlim(-129, -124)
ax[0,1].set_title('Last TH Line Transect 07-25-23 - 08-14-23')
ax[0,1].set_ylabel('Depth (m)')
plt.colorbar(contour2, label=r'Temperature ($\degree$C)')

# Temp Anomaly
contour2b = ax[1,1].contourf(Xgrid, Ygrid, t_anom_8_23, cmap='RdYlBu_r', norm=divnorm)
ax[1,1].invert_yaxis()
ax[1,1].set_xlim(-129, -124)
ax[1,1].set_title('Temperature Anomaly')
ax[1,1].set_xlabel(r'Longitude ($\degree$E)')
ax[1,1].set_ylabel('Depth (m)')
plt.colorbar(contour2b, label=r'Temperature ($\degree$C)')


# First TH Line Transect 10-13-23 - 11-16-23

# Raw Data
contour3 = ax[2,0].contourf(Xgrid, Ygrid, Z_10_23, cmap='jet')
ax[2,0].invert_yaxis()
ax[2,0].set_xlim(-129, -124)
ax[2,0].set_title('First TH Line Transect 10-13-23 - 11-16-23')
ax[2,0].set_ylabel('Depth (m)')
plt.colorbar(contour3, label=r'Temperature ($\degree$C)')

# Temp Anomaly
contour3b = ax[3,0].contourf(Xgrid, Ygrid, t_anom_10_23, cmap='RdYlBu_r', norm=divnorm)
ax[3,0].invert_yaxis()
ax[3,0].set_xlim(-129, -124)
ax[3,0].set_title('Temperature Anomaly')
ax[3,0].set_xlabel(r'Longitude ($\degree$E)')
ax[3,0].set_ylabel('Depth (m)')
plt.colorbar(contour3b, label=r'Temperature ($\degree$C)')


# Last TH Line Transect 12-28-23 - 01-24-24

# Raw Data
contour4 = ax[2,1].contourf(Xgrid, Ygrid, Z_1_24, cmap='jet')
ax[2,1].invert_yaxis()
ax[2,1].set_xlim(-129, -124)
ax[2,1].set_title('First TH Line Transect 12-28-23 - 01-24-24')
ax[2,1].set_ylabel('Depth (m)')
plt.colorbar(contour4, label=r'Temperature ($\degree$C)')

# Temp Anomaly
contour4b = ax[3,1].contourf(Xgrid, Ygrid, t_anom_1_24, cmap='RdYlBu_r', norm=divnorm)
ax[3,1].invert_yaxis()
ax[3,1].set_xlim(-129, -124)
ax[3,1].set_title('Temperature Anomaly')
ax[3,1].set_xlabel(r'Longitude ($\degree$E)')
ax[3,1].set_ylabel('Depth (m)')
plt.colorbar(contour4b, label=r'Temperature ($\degree$C)')

# %% [markdown]
# # 200km Inshore Average T-Anom Timeseries

# %% [markdown]
# ## 200km Inshore Average Data

# %%
# Assign time dimension to be datetime variables of the midway point in the transect

# Sep 2019 Deployment
tran_9_19 = np.array([datetime(2019,9,30)], dtype='datetime64')
tran_10_19 = np.array([datetime(2019,10,28)], dtype='datetime64')
tran_11_19 = np.array([datetime(2019,11,24)], dtype='datetime64')
tran_12_19 = np.array([datetime(2019,12,19)], dtype='datetime64')
tran_1_20 = np.array([datetime(2020,1,17)], dtype='datetime64')
tran_2_20 = np.array([datetime(2020,2,15)], dtype='datetime64')
tran_3_20_a = np.array([datetime(2020,3,5)], dtype='datetime64')
tran_3_20_b = np.array([datetime(2020,3,13)], dtype='datetime64')

# Sep 2020 Deployment
tran_9_20 = np.array([datetime(2020,9,29)], dtype='datetime64')
tran_10_20 = np.array([datetime(2020,10,24)], dtype='datetime64')
tran_11_20 = np.array([datetime(2020,11,19)], dtype='datetime64')
tran_12_20 = np.array([datetime(2020,12,15)], dtype='datetime64')
tran_1_21 = np.array([datetime(2021,1,10)], dtype='datetime64')
tran_2_21 = np.array([datetime(2021,2,1)], dtype='datetime64')

# Nov 2021 Deployment
tran_11_21 = np.array([datetime(2021,11,27)], dtype='datetime64')
tran_12_21 = np.array([datetime(2021,12,27)], dtype='datetime64')
tran_1_22 = np.array([datetime(2022,1,22)], dtype='datetime64')
tran_2_22 = np.array([datetime(2022,2,22)], dtype='datetime64')
tran_3_22 = np.array([datetime(2022,3,29)], dtype='datetime64')
tran_4_22 = np.array([datetime(2022,5,3)], dtype='datetime64')
tran_5_22 = np.array([datetime(2022,5,29)], dtype='datetime64')
tran_6_22 = np.array([datetime(2022,6,9)], dtype='datetime64')

# Jul 2022 Deployment
tran_8_22 = np.array([datetime(2022,8,11)], dtype='datetime64')
tran_9_22 = np.array([datetime(2022,9,15)], dtype='datetime64')
tran_10_22 = np.array([datetime(2022,10,20)], dtype='datetime64')
tran_11_22 = np.array([datetime(2022,11,27)], dtype='datetime64')
tran_12_22 = np.array([datetime(2022,12,20)], dtype='datetime64')
tran_1_23 = np.array([datetime(2023,1,19)], dtype='datetime64')

# Jan 2023 Deployment
tran_2_23 = np.array([datetime(2023,2,7)], dtype='datetime64')
tran_3_23_a = np.array([datetime(2023,3,7)], dtype='datetime64')
tran_3_23_b = np.array([datetime(2023,3,29)], dtype='datetime64')
tran_4_23 = np.array([datetime(2023,4,27)], dtype='datetime64')
tran_5_23 = np.array([datetime(2023,5,22)], dtype='datetime64')
tran_6_23 = np.array([datetime(2023,6,22)], dtype='datetime64')
tran_7_23 = np.array([datetime(2023,7,15)], dtype='datetime64')
tran_8_23 = np.array([datetime(2023,8,9)], dtype='datetime64')

# Oct 2023 Deployment
tran_10_23 = np.array([datetime(2023,11,12)], dtype='datetime64')
tran_11_23 = np.array([datetime(2023,11,28)], dtype='datetime64')
tran_12_23 = np.array([datetime(2023,12,21)], dtype='datetime64')
tran_1_24 = np.array([datetime(2024,1,10)], dtype='datetime64')
tran_2_24 = np.array([datetime(2024,2,2)], dtype='datetime64')

# %%
# Take the mean values of the inner 200km

# Sep 2019 Deployment
t_anom_avg_9_19 = np.mean(t_anom_9_19, axis=1)
t_anom_avg_10_19 = np.mean(t_anom_10_19, axis=1)
t_anom_avg_11_19 = np.mean(t_anom_11_19, axis=1)
t_anom_avg_12_19 = np.mean(t_anom_12_19, axis=1)
t_anom_avg_1_20 = np.mean(t_anom_1_20, axis=1)
t_anom_avg_2_20 = np.mean(t_anom_2_20, axis=1)
t_anom_avg_3_20_a = np.mean(t_anom_3_20_a, axis=1)
t_anom_avg_3_20_b = np.mean(t_anom_3_20_b, axis=1)

# Sep 2020 Deployment
t_anom_avg_9_20 = np.mean(t_anom_9_20, axis=1)
t_anom_avg_10_20 = np.mean(t_anom_10_20, axis=1)
t_anom_avg_11_20 = np.mean(t_anom_11_20, axis=1)
t_anom_avg_12_20 = np.mean(t_anom_12_20, axis=1)
t_anom_avg_1_21 = np.mean(t_anom_1_21, axis=1)
t_anom_avg_2_21 = np.mean(t_anom_2_21, axis=1)

# Nov 2021 Deployment
t_anom_avg_11_21 = np.mean(t_anom_11_21, axis=1)
t_anom_avg_12_21 = np.mean(t_anom_12_21, axis=1)
t_anom_avg_1_22 = np.mean(t_anom_1_22, axis=1)
t_anom_avg_2_22 = np.mean(t_anom_2_22, axis=1)
t_anom_avg_3_22 = np.mean(t_anom_3_22, axis=1)
t_anom_avg_4_22 = np.mean(t_anom_4_22, axis=1)
t_anom_avg_5_22 = np.mean(t_anom_5_22, axis=1)
t_anom_avg_6_22 = np.mean(t_anom_6_22, axis=1)

# Jul 2022 Deployment
t_anom_avg_8_22 = np.mean(t_anom_8_22, axis=1)
t_anom_avg_9_22 = np.mean(t_anom_9_22, axis=1)
t_anom_avg_10_22 = np.mean(t_anom_10_22, axis=1)
t_anom_avg_11_22 = np.mean(t_anom_11_22, axis=1)
t_anom_avg_12_22 = np.mean(t_anom_12_22, axis=1)
t_anom_avg_1_23 = np.mean(t_anom_1_23, axis=1)

# Jan 2023 Deployment
t_anom_avg_2_23 = np.mean(t_anom_2_23, axis=1)
t_anom_avg_3_23_a = np.mean(t_anom_3_23_a, axis=1)
t_anom_avg_3_23_b = np.mean(t_anom_3_23_b, axis=1)
t_anom_avg_4_23 = np.mean(t_anom_4_23, axis=1)
t_anom_avg_5_23 = np.mean(t_anom_5_23, axis=1)
t_anom_avg_6_23 = np.mean(t_anom_6_23, axis=1)
t_anom_avg_7_23 = np.mean(t_anom_7_23, axis=1)
t_anom_avg_8_23 = np.mean(t_anom_8_23, axis=1)

# Oct 2023 Deployment
t_anom_avg_10_23 = np.mean(t_anom_10_23, axis=1)
t_anom_avg_11_23 = np.mean(t_anom_11_23, axis=1)
t_anom_avg_12_23 = np.mean(t_anom_12_23, axis=1)
t_anom_avg_1_24 = np.mean(t_anom_1_24, axis=1)
t_anom_avg_2_24 = np.mean(t_anom_2_24, axis=1)

# %%
# Convert numpy arrays to xarray DataArrays

# Sep 2019 Deployment
t_anom_avg_9_19 = xr.DataArray(t_anom_avg_9_19)
t_anom_avg_10_19 = xr.DataArray(t_anom_avg_10_19)
t_anom_avg_11_19 = xr.DataArray(t_anom_avg_11_19)
t_anom_avg_12_19 = xr.DataArray(t_anom_avg_12_19)
t_anom_avg_1_20 = xr.DataArray(t_anom_avg_1_20)
t_anom_avg_2_20 = xr.DataArray(t_anom_avg_2_20)
t_anom_avg_3_20_a = xr.DataArray(t_anom_avg_3_20_a)
t_anom_avg_3_20_b = xr.DataArray(t_anom_avg_3_20_b)

# Sep 2020 Deployment
t_anom_avg_9_20 = xr.DataArray(t_anom_avg_9_20)
t_anom_avg_10_20 = xr.DataArray(t_anom_avg_10_20)
t_anom_avg_11_20 = xr.DataArray(t_anom_avg_11_20)
t_anom_avg_12_20 = xr.DataArray(t_anom_avg_12_20)
t_anom_avg_1_21 = xr.DataArray(t_anom_avg_1_21)
t_anom_avg_2_21 = xr.DataArray(t_anom_avg_2_21)

# Nov 2021 Deployment
t_anom_avg_11_21 = xr.DataArray(t_anom_avg_11_21)
t_anom_avg_12_21 = xr.DataArray(t_anom_avg_12_21)
t_anom_avg_1_22 = xr.DataArray(t_anom_avg_1_22)
t_anom_avg_2_22 = xr.DataArray(t_anom_avg_2_22)
t_anom_avg_3_22 = xr.DataArray(t_anom_avg_3_22)
t_anom_avg_4_22 = xr.DataArray(t_anom_avg_4_22)
t_anom_avg_5_22 = xr.DataArray(t_anom_avg_5_22)
t_anom_avg_6_22 = xr.DataArray(t_anom_avg_6_22)

# Jul 2022 Deployment
t_anom_avg_8_22 = xr.DataArray(t_anom_avg_8_22)
t_anom_avg_9_22 = xr.DataArray(t_anom_avg_9_22)
t_anom_avg_10_22 = xr.DataArray(t_anom_avg_10_22)
t_anom_avg_11_22 = xr.DataArray(t_anom_avg_11_22)
t_anom_avg_12_22 = xr.DataArray(t_anom_avg_12_22)
t_anom_avg_1_23 = xr.DataArray(t_anom_avg_1_23)

# Jan 2023 Deployment
t_anom_avg_2_23 = xr.DataArray(t_anom_avg_2_23)
t_anom_avg_3_23_a = xr.DataArray(t_anom_avg_3_23_a)
t_anom_avg_3_23_b = xr.DataArray(t_anom_avg_3_23_b)
t_anom_avg_4_23 = xr.DataArray(t_anom_avg_4_23)
t_anom_avg_5_23 = xr.DataArray(t_anom_avg_5_23)
t_anom_avg_6_23 = xr.DataArray(t_anom_avg_6_23)
t_anom_avg_7_23 = xr.DataArray(t_anom_avg_7_23)
t_anom_avg_8_23 = xr.DataArray(t_anom_avg_8_23)

# Oct 2023 Deployment
t_anom_avg_10_23 = xr.DataArray(t_anom_avg_10_23)
t_anom_avg_11_23 = xr.DataArray(t_anom_avg_11_23)
t_anom_avg_12_23 = xr.DataArray(t_anom_avg_12_23)
t_anom_avg_1_24 = xr.DataArray(t_anom_avg_1_24)
t_anom_avg_2_24 = xr.DataArray(t_anom_avg_2_24)

# %%
# Replace the time dimension with the datetime value

# Sep 2019 Deployment
t_anom_avg_9_19 = t_anom_avg_9_19.expand_dims(time=tran_9_19)
t_anom_avg_10_19 = t_anom_avg_10_19.expand_dims(time=tran_10_19)
t_anom_avg_11_19 = t_anom_avg_11_19.expand_dims(time=tran_11_19)
t_anom_avg_12_19 = t_anom_avg_12_19.expand_dims(time=tran_12_19)
t_anom_avg_1_20 = t_anom_avg_1_20.expand_dims(time=tran_1_20)
t_anom_avg_2_20 = t_anom_avg_2_20.expand_dims(time=tran_2_20)
t_anom_avg_3_20_a = t_anom_avg_3_20_a.expand_dims(time=tran_3_20_a)
t_anom_avg_3_20_b = t_anom_avg_3_20_b.expand_dims(time=tran_3_20_b)

# Sep 2020 Deployment
t_anom_avg_9_20 = t_anom_avg_9_20.expand_dims(time=tran_9_20)
t_anom_avg_10_20 = t_anom_avg_10_20.expand_dims(time=tran_10_20)
t_anom_avg_11_20 = t_anom_avg_11_20.expand_dims(time=tran_11_20)
t_anom_avg_12_20 = t_anom_avg_12_20.expand_dims(time=tran_12_20)
t_anom_avg_1_21 = t_anom_avg_1_21.expand_dims(time=tran_1_21)

# Nov 2021 Deployment
t_anom_avg_11_21 = t_anom_avg_11_21.expand_dims(time=tran_11_21)
t_anom_avg_12_21 = t_anom_avg_12_21.expand_dims(time=tran_12_21)
t_anom_avg_1_22 = t_anom_avg_1_22.expand_dims(time=tran_1_22)
t_anom_avg_2_22 = t_anom_avg_2_22.expand_dims(time=tran_2_22)
t_anom_avg_3_22 = t_anom_avg_3_22.expand_dims(time=tran_3_22)
t_anom_avg_4_22 = t_anom_avg_4_22.expand_dims(time=tran_4_22)
t_anom_avg_5_22 = t_anom_avg_5_22.expand_dims(time=tran_5_22)
t_anom_avg_6_22 = t_anom_avg_6_22.expand_dims(time=tran_6_22)

# Jul 2022 Deployment
t_anom_avg_8_22 = t_anom_avg_8_22.expand_dims(time=tran_8_22)
t_anom_avg_9_22 = t_anom_avg_9_22.expand_dims(time=tran_9_22)
t_anom_avg_10_22 = t_anom_avg_10_22.expand_dims(time=tran_10_22)
t_anom_avg_11_22 = t_anom_avg_11_22.expand_dims(time=tran_11_22)
t_anom_avg_12_22 = t_anom_avg_12_22.expand_dims(time=tran_12_22)
t_anom_avg_1_23 = t_anom_avg_1_23.expand_dims(time=tran_1_23)

# Jan 2023 Deployment
t_anom_avg_2_23 = t_anom_avg_2_23.expand_dims(time=tran_2_23)
t_anom_avg_3_23_a = t_anom_avg_3_23_a.expand_dims(time=tran_3_23_a)
t_anom_avg_3_23_b = t_anom_avg_3_23_b.expand_dims(time=tran_3_23_b)
t_anom_avg_4_23 = t_anom_avg_4_23.expand_dims(time=tran_4_23)
t_anom_avg_5_23 = t_anom_avg_5_23.expand_dims(time=tran_5_23)
t_anom_avg_6_23 = t_anom_avg_6_23.expand_dims(time=tran_6_23)
t_anom_avg_7_23 = t_anom_avg_7_23.expand_dims(time=tran_7_23)
t_anom_avg_8_23 = t_anom_avg_8_23.expand_dims(time=tran_8_23)

# Oct 2023 Deployment
t_anom_avg_10_23 = t_anom_avg_10_23.expand_dims(time=tran_10_23)
t_anom_avg_11_23 = t_anom_avg_11_23.expand_dims(time=tran_11_23)
t_anom_avg_12_23 = t_anom_avg_12_23.expand_dims(time=tran_12_23)
t_anom_avg_1_24 = t_anom_avg_1_24.expand_dims(time=tran_1_24)
t_anom_avg_2_24 = t_anom_avg_2_24.expand_dims(time=tran_2_24)

# %%
t_anom_avg_9_19
# Out:
# <xarray.DataArray 't_an' (time: 1, depth: 200)>
# array([[ 2.75300424e+00,  3.05566340e+00,  3.21200912e+00,
#          3.18304441e+00,  3.14211130e+00,  2.71638042e+00,
#          2.18792497e+00,  1.29064030e+00,  6.30772201e-01,
#          2.07693829e-01,  4.25197578e-01,  4.40988560e-01,
#          3.50196607e-01,  4.76976236e-01,  4.36651003e-01,
#          4.11610477e-01,  4.81716789e-01,  4.32422507e-01,
#          4.50844554e-01,  5.17471697e-01,  5.23061425e-01,
#          5.10599169e-01,  4.73749167e-01,  4.63696870e-01,
#          5.06482803e-01,  4.77753174e-01,  4.91327802e-01,
#          4.99494008e-01,  5.36776587e-01,  5.11305369e-01,
#          4.15135345e-01,  3.41476060e-01,  5.09352044e-01,
#          4.59368460e-01,  3.73152187e-01,  4.19931773e-01,
#          4.96638176e-01,  4.46534000e-01,  2.42102954e-01,
#          3.54177035e-01,  2.94269292e-01,  3.52749484e-01,
#          3.22885302e-01,  3.38109598e-01,  2.87764037e-01,
# ...

# %%
# Combine all of the individual transects into one array
combined_data = xr.combine_by_coords([t_anom_avg_9_19, t_anom_avg_10_19, t_anom_avg_11_19, t_anom_avg_12_19, t_anom_avg_1_20, t_anom_avg_2_20, t_anom_avg_3_20_a, t_anom_avg_3_20_b,   # Sep 2019 Deployment
                                      t_anom_avg_9_20, t_anom_avg_10_20, t_anom_avg_11_20, t_anom_avg_12_20, t_anom_avg_1_21,   # Sep 2020 Deployment
                                      t_anom_avg_11_21, t_anom_avg_12_21, t_anom_avg_1_22, t_anom_avg_2_22, t_anom_avg_3_22, t_anom_avg_4_22, t_anom_avg_5_22, t_anom_avg_6_22,   # Nov 2021 Deployment
                                      t_anom_avg_8_22, t_anom_avg_9_22, t_anom_avg_10_22, t_anom_avg_11_22, t_anom_avg_12_22, t_anom_avg_1_23,   # Jul 2022 Deployment
                                     t_anom_avg_2_23, t_anom_avg_3_23_a, t_anom_avg_3_23_b, t_anom_avg_4_23, t_anom_avg_5_23, t_anom_avg_6_23, t_anom_avg_7_23, t_anom_avg_8_23,   # Jan 2023 Deployment
                                     t_anom_avg_10_23, t_anom_avg_11_23, t_anom_avg_12_23, t_anom_avg_1_24, t_anom_avg_2_24]   # Oct 2023 Deployment
                                    )

# Generate a regular grid to interpolate the data
xgrid = np.arange(datetime(2019,9,16), datetime(2024,2,2), timedelta(days=30)).astype(datetime)
ygrid = np.arange(0,1000, 5)

# Interpolate the data over the new grid
combined_data_new = combined_data.interp(time=xgrid,depth=ygrid)

# Redefine the variables under the new interpolated array
time_Xgrid, depth_Ygrid = np.meshgrid(combined_data_new['time'], combined_data_new['depth'])

temp = combined_data_new['t_an'].T

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Boundaries

# %%
# Set Colorbar and Contour Line Ranges

boundaries = [-4, -3.5, -3, -2.5, -2, -1.5, -1, -0.5, 0, 0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4]
levels = [-4, -3.5, -3, -2.5, -2, -1.5, -1, -0.5, 0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4]
dates = np.arange(datetime(2019,9,1), datetime(2024,3,1), timedelta(days=30)).astype(datetime)
# date_form = DateFormatter("%Y")
date_form = DateFormatter("%b %Y")
divnorm=colors.TwoSlopeNorm(vcenter=0., vmin=-4, vmax=4)

# %% [markdown]
# ### Contour Plot

# %%
# Plot the figure

fig, ax = plt.subplots(figsize=(14,4), dpi=300)

plot = ax.contourf(time_Xgrid, depth_Ygrid, temp, cmap='RdYlBu_r', norm=divnorm, levels=boundaries)
lines = ax.contour(time_Xgrid, depth_Ygrid, temp, colors='black', norm=divnorm, levels=levels, alpha=0.75)
deployment_sep_19 = ax.hlines(y=570, xmin=datetime(2019,9,16), xmax=datetime(2020,3,19), color='k')
deployment_sep_20 = ax.hlines(y=570, xmin=datetime(2020,9,16), xmax=datetime(2021,2,6), color='k')
deployment_nov_21 = ax.hlines(y=570, xmin=datetime(2021,11,12), xmax=datetime(2022,6,16), color='k')
deployment_jul_22 = ax.hlines(y=570, xmin=datetime(2022,7,29), xmax=datetime(2023,1,26), color='k')
deployment_jan_23 = ax.hlines(y=570, xmin=datetime(2023,1,26), xmax=datetime(2023,8,14), color='k')
deployment_oct_23 = ax.hlines(y=570, xmin=datetime(2023,10,13), xmax=xgrid.max(), color='k')
ax.clabel(lines, lines.levels, inline=True, fontsize=10)
ax.invert_yaxis()
ax.set_ylabel('Depth (m)')
ax.set_xlabel('Year')
# ax.set_xlim(time_Xgrid.min(), time_Xgrid.max())
ax.set_yticks((0, 200, 400, 600))
ax.xaxis.set_major_formatter(date_form)
ax.set_ylim(600, 0)
ax.spines[:].set_linewidth(2)
ax.tick_params(width=2, top=True, right=True, direction='in')
ax.set_title('Trinidad Head Temperature Anomaly \n Averaged Over Inshore 200km', pad=10)
cbar = plt.colorbar(plot, label=r'Temperature Anomaly ($\degree$C)', shrink=0.5,location='right', pad=0.015)
cbar.outline.set_linewidth(2)

# %% [markdown]
# ### Scatter Plot

# %%
# Plot the figure

fig, ax = plt.subplots(figsize=(14,4), dpi=300)

plot = ax.scatter(time_Xgrid, depth_Ygrid, c=temp, cmap='RdYlBu_r', norm=divnorm)
deployment_sep_19 = ax.hlines(y=570, xmin=datetime(2019,9,16), xmax=datetime(2020,3,19), color='k')
deployment_sep_20 = ax.hlines(y=570, xmin=datetime(2020,9,16), xmax=datetime(2021,2,6), color='k')
deployment_nov_21 = ax.hlines(y=570, xmin=datetime(2021,11,12), xmax=datetime(2022,6,16), color='k')
deployment_jul_22 = ax.hlines(y=570, xmin=datetime(2022,7,29), xmax=datetime(2023,1,26), color='k')
deployment_jan_23 = ax.hlines(y=570, xmin=datetime(2023,1,26), xmax=datetime(2023,8,14), color='k')
deployment_oct_23 = ax.hlines(y=570, xmin=datetime(2023,10,13), xmax=xgrid.max(), color='k')
ax.invert_yaxis()
ax.set_ylabel('Depth (m)')
ax.set_xlabel('Time')
ax.set_yticks((0, 200, 400, 600))
ax.xaxis.set_major_formatter(date_form)
ax.set_ylim(600, 0)
ax.spines[:].set_linewidth(2)
ax.tick_params(width=2, top=True, right=True, direction='in')
ax.set_title('Trinidad Head Temperature Anomaly \n Averaged Over Inshore 200km', pad=10)
cbar = plt.colorbar(plot, label=r'Temperature Anomaly ($\degree$C)', shrink=0.5,location='right', pad=0.015)
cbar.outline.set_linewidth(2)
